# %%
import cv2

# %%
img = cv2.imread('orig.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
store = cv2.imread('store.jpg')
store = cv2.cvtColor(store, cv2.COLOR_BGR2RGB)

# %%
plt.figure()
plt.imshow(img) 
plt.show()  # display it

# %%
# %matplotlib inline
plt.figure()
plt.imshow(store) 
plt.show()  # display it

# %%
bit = cv2.bitwise_or(img, store)

# %%
# %matplotlib inline
plt.figure()
plt.imshow(bit) 
plt.show()  # display it
